# %% [markdown]
# # 예측 데이터셋 (ETTh1) EDA

# %%
from pathlib import Path
import os, sys, json, pandas as pd, numpy as np
ROOT = Path.cwd().resolve()
if not (ROOT / 'src').exists():
    ROOT = ROOT.parent
os.chdir(ROOT)
if str(ROOT) not in sys.path:
    sys.path.append(str(ROOT))

# %%
# !{sys.executable} scripts/analyze_dataset.py --task forecast --config src/configs/forecast_timexer.yaml
# Out:
# {'raw': {'n_rows': 17420, 'n_features': 7, 'features': ['HUFL', 'HULL', 'MUFL', 'MULL', 'LUFL', 'LULL', 'OT']}, 'processed_train': {'n_rows': 12194, 'n_features': 7, 'features': ['HUFL', 'HULL', 'MUFL', 'MULL', 'LUFL', 'LULL', 'OT']}}

# %%
import pandas as pd
summary = pd.read_json(ROOT / 'results/forecast/timexer/analysis/forecast/summary.json')
summary
# Out:
#                                                  raw  \
# n_rows                                         17420
# n_features                                         7
# features    [HUFL, HULL, MUFL, MULL, LUFL, LULL, OT]
#
#                                      processed_train
# n_rows                                         12194
# n_features                                         7
# features    [HUFL, HULL, MUFL, MULL, LUFL, LULL, OT]
