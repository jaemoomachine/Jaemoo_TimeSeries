# %% [markdown]
# # 이상치 탐지 데이터셋 (PSM) EDA

# %%
from pathlib import Path
import os, sys, json, pandas as pd, numpy as np
ROOT = Path.cwd().resolve()
if not (ROOT / 'src').exists():
    ROOT = ROOT.parent
os.chdir(ROOT)
if str(ROOT) not in sys.path:
    sys.path.append(str(ROOT))

# %%
# !{sys.executable} scripts/analyze_dataset.py --task anomaly --config src/configs/anomaly_timexer.yaml
# Out:
# [Anomaly Loader Build Summary]
#   train windows: 14895 | val windows: 1654 | test windows: 10969
#   n_endo=25 n_exo=0
# {'raw': {'n_rows': 132481, 'n_features': 25, 'features': ['feature_0', 'feature_1', 'feature_2', 'feature_3', 'feature_4', 'feature_5', 'feature_6', 'feature_7', 'feature_8', 'feature_9', 'feature_10', 'feature_11', 'feature_12', 'feature_13', 'feature_14', 'feature_15', 'feature_16', 'feature_17', 'feature_18', 'feature_19', 'feature_20', 'feature_21', 'feature_22', 'feature_23', 'feature_24']}, 'processed_train': {'n_rows': 132481, 'n_features': 25, 'features': ['feature_0', 'feature_1', 'feature_2', 'feature_3', 'feature_4', 'feature_5', 'feature_6', 'feature_7', 'feature_8', 'feature_9', 'feature_10', 'feature_11', 'feature_12', 'feature_13', 'feature_14', 'feature_15', 'feature_16', 'feature_17', 'feature_18', 'feature_19', 'feature_20', 'feature_21', 'feature_22', 'feature_23', 'feature_24']}}
# [Anomaly Loader Build Summary]
#   train windows: 14895 | val windows: 1654 | test windows: 10969
#   n_endo=25 n_exo=0
# {'raw': {'n_rows': 132481, 'n_features': 25, 'features': ['feature_0', 'feature_1', 'feature_2', 'feature_3', 'feature_4', 'feature_5', 'feature_6', 'feature_7', 'feature_8', 'feature_9', 'feature_10', 'feature_11', 'feature_12', 'feature_13', 'feature_14', 'feature_15', 'feature_16', 'feature_17', 'feature_18', 'feature_19', 'feature_20', 'feature_21', 'feature_22', 'feature_23', 'feature_24']}, 'processed_train': {'n_rows': 132481, 'n_features': 25, 'features': ['feature_0', 'feature_1', 'feature_2', 'feature_3', 'feature_4', 'feature_5', 'feature_6', 'feature_7', 'feature_8', 'feature_9', 'feature_10', 'feature_11', 'feature_12', 'feature_13', 'feature_14', 'feature_15', 'feature_16', 'feature_17', 'feature_18', 'feature_19', 'feature_20', 'feature_21', 'feature_22', 'feature_23', 'feature_24']}}
