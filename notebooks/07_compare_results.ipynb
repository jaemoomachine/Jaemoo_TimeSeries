# %% [markdown]
# # 과업별 모델 비교

# %%
from pathlib import Path
import os, sys, json, pandas as pd, numpy as np
ROOT = Path.cwd().resolve()
if not (ROOT / 'src').exists():
    ROOT = ROOT.parent
os.chdir(ROOT)
if str(ROOT) not in sys.path:
    sys.path.append(str(ROOT))
print('ROOT =', ROOT)
# Out:
# ROOT = C:\Users\deepd\Desktop\SNU_Coding\ts_unified_timexer_repo_fixed_heads\ts_unified_timexer_repo

# %%
forecast = pd.read_csv(ROOT / 'results/benchmarks/forecast_benchmark_summary.csv') if (ROOT / 'results/benchmarks/forecast_benchmark_summary.csv').exists() else None
anomaly = pd.read_csv(ROOT / 'results/benchmarks/anomaly_benchmark_summary.csv') if (ROOT / 'results/benchmarks/anomaly_benchmark_summary.csv').exists() else None
classification = pd.read_csv(ROOT / 'results/benchmarks/classification_benchmark_summary.csv') if (ROOT / 'results/benchmarks/classification_benchmark_summary.csv').exists() else None
forecast, anomaly, classification
# Out:
# (                                    config      task     model_name       mse  \
#  0    src/configs/forecast_transformer.yaml  forecast    transformer  0.117531
#  1        src/configs/forecast_timexer.yaml  forecast        timexer  0.111974
#  2  src/configs/forecast_timexer_revin.yaml  forecast  timexer_revin  0.114868
#  3    src/configs/forecast_timexer_nst.yaml  forecast    timexer_nst  0.110491
#
#          mae      rmse      loss
#  0  0.267544  0.342828  0.117531
#  1  0.257627  0.334625  0.111974
#  2  0.260748  0.338921  0.114868
#  3  0.255022  0.332402  0.110491  ,
#                                     config     task     model_name  threshold  \
#  0    src/configs/anomaly_transformer.yaml  anomaly    transformer   0.153640
#  1        src/configs/anomaly_timexer.yaml  anomaly        timexer   0.035446
#  2  src/configs/anomaly_timexer_revin.yaml  anomaly  timexer_revin   0.027266
#  3    src/configs/anomaly_timexer_nst.yaml  anomaly    timexer_nst   0.026579
#
# ...
