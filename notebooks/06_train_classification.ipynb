# %% [markdown]
# # 시계열 분류

# %%
from pathlib import Path
import os, sys, json, pandas as pd, numpy as np
ROOT = Path.cwd().resolve()
if not (ROOT / 'src').exists():
    ROOT = ROOT.parent
os.chdir(ROOT)
if str(ROOT) not in sys.path:
    sys.path.append(str(ROOT))

# %%
# !{sys.executable} scripts/run_benchmark_suite.py --task classification --configs \
  src/configs/classification_transformer.yaml \
  src/configs/classification_timexer.yaml \
  src/configs/classification_timexer_revin.yaml \
  src/configs/classification_timexer_nst.yaml
# Out:
# {'config': 'src/configs/classification_transformer.yaml', 'task': 'classification', 'model_name': 'transformer', 'accuracy': 1.0, 'macro_f1': 1.0, 'loss': 0.3162425637245178}
# {'config': 'src/configs/classification_timexer.yaml', 'task': 'classification', 'model_name': 'timexer', 'accuracy': 0.95, 'macro_f1': 0.9494949494949495, 'loss': 0.211506237834692}
# {'config': 'src/configs/classification_timexer_revin.yaml', 'task': 'classification', 'model_name': 'timexer_revin', 'accuracy': 0.95, 'macro_f1': 0.9484126984126984, 'loss': 0.22205636724829675}
# {'config': 'src/configs/classification_timexer_nst.yaml', 'task': 'classification', 'model_name': 'timexer_nst', 'accuracy': 0.975, 'macro_f1': 0.974937343358396, 'loss': 0.4175136208534241}
#                                           config  ...      loss
# 0    src/configs/classification_transformer.yaml  ...  0.316243
# 1        src/configs/classification_timexer.yaml  ...  0.211506
# ...

# %%
df = pd.read_csv(ROOT / 'results/benchmarks/classification_benchmark_summary.csv')
df
# Out:
#                                           config            task  \
# 0    src/configs/classification_transformer.yaml  classification
# 1        src/configs/classification_timexer.yaml  classification
# 2  src/configs/classification_timexer_revin.yaml  classification
# 3    src/configs/classification_timexer_nst.yaml  classification
#
#       model_name  accuracy  macro_f1      loss
# 0    transformer     1.000  1.000000  0.316243
# 1        timexer     0.950  0.949495  0.211506
# 2  timexer_revin     0.950  0.948413  0.222056
# 3    timexer_nst     0.975  0.974937  0.417514

# %%
# !{sys.executable} scripts/compare_results.py --task classification --csv results/benchmarks/classification_benchmark_summary.csv
# Out:
#                                           config  ...      loss
# 0    src/configs/classification_transformer.yaml  ...  0.316243
# 3    src/configs/classification_timexer_nst.yaml  ...  0.417514
# 1        src/configs/classification_timexer.yaml  ...  0.211506
# 2  src/configs/classification_timexer_revin.yaml  ...  0.222056
#
# [4 rows x 6 columns]
