# %% [markdown]
# (1) 예측 데이터셋 (ETTh1)

# %%
import pandas as pd
pd.read_csv("../results/forecast/timexer/analysis/forecast/raw/descriptive_statistics.csv", index_col=0)
# Out:
#         count       mean       std        min    25%     50%     75%  \
# HUFL  17420.0   7.375141  7.067744 -22.705999  5.827   8.774  11.788
# HULL  17420.0   2.242242  2.042342  -4.756000  0.737   2.210   3.684
# MUFL  17420.0   4.300239  6.826978 -25.087999  3.296   5.970   8.635
# MULL  17420.0   0.881568  1.809293  -5.934000 -0.284   0.959   2.203
# LUFL  17420.0   3.066062  1.164506  -1.188000  2.315   2.833   3.625
# LULL  17420.0   0.856932  0.599552  -1.371000  0.670   0.975   1.218
# OT    17420.0  13.324672  8.566946  -4.080000  6.964  11.396  18.079
#
#             max      skew
# HUFL  23.643999 -1.377876
# HULL  10.114000  0.100963
# MUFL  17.341000 -1.605226
# MULL   7.747000 -0.138206
# LUFL   8.498000  1.266531
# LULL   3.046000 -1.362274
# OT    46.007000  0.968199

# %% [markdown]
# (2) 이상치 탐지 데이터셋 (PSM)
# - 결측치 존재

# %%
pd.read_csv("../results/anomaly/timexer/analysis/anomaly/raw/descriptive_statistics.csv", index_col=0)
# Out:
#                count      mean       std       min       25%       50%  \
# feature_0   132481.0  0.835810  0.067326  0.486490  0.789497  0.837290
# feature_1   132481.0  0.840205  0.039472  0.525682  0.820488  0.843873
# feature_2   132481.0  0.634216  0.102920  0.421484  0.580170  0.603304
# feature_3   132481.0  0.575081  0.049675  0.380874  0.543702  0.572077
# feature_4   132279.0  0.543310  0.089438  0.065106  0.471135  0.548428
# feature_5   132232.0  0.511753  0.077771  0.110161  0.451409  0.507439
# feature_6   131918.0  0.549268  0.064093  0.215909  0.505682  0.539773
# feature_7   132434.0  0.537706  0.090120  0.077795  0.470921  0.529834
# feature_8   132434.0  0.551133  0.078996  0.038693  0.490750  0.552253
# feature_9   132481.0  0.545177  0.081033  0.040358  0.482553  0.545577
# feature_10  132434.0  0.536872  0.077413  0.039544  0.478396  0.537551
# feature_11  132481.0  0.594350  0.091992  0.055413  0.528724  0.587961
# ...

# %% [markdown]
# (3) 분류 데이터셋 (UEA)
# - 길이 100의 시계열 훈련 40개, 테스트 40개 샘플
# - 40개 샘플이 하나의 시계열이라고 봤을 때의 요약 통계량

# %%
pd.read_csv("../results/classification/timexer/analysis/classification/raw/shape_summary.csv", index_col=0)
# Out:
#              num_channels  seq_len  num_classes  total_missing
# num_samples
# 40                      6      100            4              0

# %%
pd.read_csv("../results/classification/timexer/analysis/classification/raw/descriptive_statistics.csv", index_col=0)
# Out:
#            count      mean       std        min       25%       50%       75%  \
# channel
# channel_0   4000  2.552760  7.073190 -22.462128 -0.281125  0.312150  4.268634
# channel_1   4000 -1.303937  6.794940 -27.822042 -3.589513 -0.271776  1.334675
# channel_2   4000 -1.026581  3.546818 -24.715273 -1.743507 -0.195069  0.279323
# channel_3   4000  0.019051  2.112185 -18.968540 -0.530677  0.000000  0.575289
# channel_4   4000 -0.023958  1.820976 -18.467825 -0.412823 -0.010653  0.279654
# channel_5   4000 -0.055790  3.517021 -24.516344 -0.991441  0.054599  1.209837
#
#                  max      skew
# channel
# channel_0  29.363152  0.651449
# channel_1  24.805077 -0.306738
# channel_2  19.523338 -1.437703
# channel_3  34.866211  1.008992
# channel_4  18.212141 -0.736466
# channel_5  13.948082 -1.188646
