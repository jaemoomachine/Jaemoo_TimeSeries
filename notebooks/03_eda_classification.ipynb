# %% [markdown]
# # 분류 데이터셋 (UEA BasicMotions) EDA

# %%
from pathlib import Path
import os, sys, json, pandas as pd, numpy as np
ROOT = Path.cwd().resolve()
if not (ROOT / 'src').exists():
    ROOT = ROOT.parent
os.chdir(ROOT)
if str(ROOT) not in sys.path:
    sys.path.append(str(ROOT))

# %%
# !{sys.executable} scripts/analyze_dataset.py --task classification --config src/configs/classification_timexer.yaml
# Out:
# {'raw': {'n_samples': 40, 'n_channels': 6, 'seq_len': 100, 'num_classes': 4, 'class_names': ['Standing', 'Running', 'Walking', 'Badminton']}, 'processed_train': {'n_samples': 40, 'n_channels': 6, 'seq_len': 100, 'num_classes': 4, 'class_names': ['Standing', 'Running', 'Walking', 'Badminton']}}
